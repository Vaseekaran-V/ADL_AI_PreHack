# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import cross_val_score
from sklearn.preprocessing import OneHotEncoder
from sklearn.pipeline import Pipeline
from sklearn import preprocessing
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import StandardScaler #you can use minmax scaler too
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.model_selection import RandomizedSearchCV
#Import other necessary model libraries, for this example, using Logistic Regression

# %%
train_data = pd.read_csv("data/train_dataset.csv")

# %%
train_data.tail()
# Out:
#        primary_identifier device_type device_category  gender district_name  \
# 10495             1438655          4G      Smartphone    MALE      Kalutara
# 10496             7827264          4G      Smartphone  FEMALE       Colombo
# 10497             1433957          4G      Smartphone  FEMALE       Colombo
# 10498             8494507          4G      Smartphone    MALE         Kandy
# 10499             3569439          3G      Smartphone    MALE      Puttalam
#
#       age_group  network_stay  average_monthly_bill_amount  dusage_sum  \
# 10495     40-50            64                      2088.13       479.0
# 10496       <20             6                      2053.50     23168.0
# 10497     30-40            69                      2827.33      4553.0
# 10498     60-70           233                       645.43      2069.0
# 10499     40-50            33                       498.20       536.0
#
#        dusage_min  ...  vusage_offnet_max  vusage_offnet_min  \
# 10495    0.346959  ...          29.866667                0.0
# 10496    0.219985  ...          25.366667                0.0
# 10497    4.831711  ...           0.000000                0.0
# 10498    4.722031  ...          18.650000                0.0
# 10499    0.003048  ...           4.366667                0.0
#
#        vusage_offnet_days  vusage_offnet_avg  vusage_offnet_stddev  \
# 10495                 7.0          14.571429              8.017054
# 10496                 3.0          10.861111              5.151029
# 10497                 0.0                NaN              0.000000
# 10498                18.0           5.887963              4.956822
# 10499                 7.0           2.228571              1.096541
#
#        number_of_fixed_bb_accounts  number_of_iptv_accounts  \
# 10495                          0.0                      0.0
# 10496                          0.0                      0.0
# 10497                          0.0                      1.0
# 10498                          0.0                      1.0
# 10499                          0.0                      0.0
#
#        add_on_tot_rental  add_on_count  next_month_plan
# 10495                NaN           NaN             PKG6
# 10496              580.0           3.0             PKG1
# 10497                NaN           NaN             PKG6
# 10498                NaN           NaN             PKG1
# 10499                NaN           NaN             PKG1
#
# [5 rows x 31 columns]

# %%
train_data['next_month_plan'] = train_data['next_month_plan'].astype('category')

# %%
train_data['next_month_plan'].unique()
# Out:
# ['PKG2', 'PKG1', 'PKG6', 'PKG4', 'PKG5', 'PKG3', 'PKG8', 'PKG7']
# Categories (8, object): ['PKG2', 'PKG1', 'PKG6', 'PKG4', 'PKG5', 'PKG3', 'PKG8', 'PKG7']

# %%
labels_x = ['PKG0','PKG1', 'PKG2', 'PKG3', 'PKG4', 'PKG5', 'PKG6', 'PKG7', 'PKG8']

# %%
le = preprocessing.LabelEncoder()

# %%
le.fit(labels_x)
# Out:
# LabelEncoder()

# %%
le.classes_
# Out:
# array(['PKG0', 'PKG1', 'PKG2', 'PKG3', 'PKG4', 'PKG5', 'PKG6', 'PKG7',
#        'PKG8'], dtype='<U4')

# %%
train_data['encoded_class_labels'] = le.transform(train_data['next_month_plan'])

# %%
train_data.head()
# Out:
#    primary_identifier device_type device_category  gender district_name  \
# 0             6875768          4G      Smartphone    MALE       Kegalle
# 1             6406277          4G      Smartphone    MALE         Galle
# 2             3563570          4G      Smartphone    MALE         Kandy
# 3             1853666          4G      Smartphone  FEMALE       Colombo
# 4             2794331          4G      Smartphone  FEMALE         Kandy
#
#   age_group  network_stay  average_monthly_bill_amount  dusage_sum  \
# 0     40-50           219                       761.62      6317.0
# 1     40-50            36                      2482.52     28365.0
# 2     30-40           186                      1565.55     18581.0
# 3     40-50            24                      2397.49     91071.0
# 4     50-60            37                      2501.75     19736.0
#
#    dusage_min  ...  vusage_offnet_min  vusage_offnet_days  vusage_offnet_avg  \
# 0    2.773958  ...                0.0                27.0          25.099383
# 1    3.079438  ...                0.0                15.0           5.071111
# 2   48.193713  ...                0.0                 0.0                NaN
# 3   22.437842  ...                0.0                 0.0                NaN
# 4   53.302092  ...                0.0                23.0          11.256522
#
#    vusage_offnet_stddev  number_of_fixed_bb_accounts  number_of_iptv_accounts  \
# 0             34.759221                          0.0                      1.0
# 1              6.779644                          0.0                      0.0
# 2              0.000000                          0.0                      0.0
# 3              0.000000                          0.0                      0.0
# 4             16.224071                          0.0                      1.0
#
#    add_on_tot_rental  add_on_count  next_month_plan  encoded_class_labels
# 0                NaN           NaN             PKG2                     2
# 1              600.0           2.0             PKG1                     1
# 2                0.0           1.0             PKG6                     6
# 3             1110.0           2.0             PKG4                     4
# 4             1350.0           2.0             PKG4                     4
#
# [5 rows x 32 columns]

# %%
train_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10500 entries, 0 to 10499
# Data columns (total 32 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   primary_identifier           10500 non-null  int64
#  1   device_type                  10477 non-null  object
#  2   device_category              10470 non-null  object
#  3   gender                       10365 non-null  object
#  4   district_name                10500 non-null  object
#  5   age_group                    10365 non-null  object
#  6   network_stay                 10500 non-null  int64
#  7   average_monthly_bill_amount  10500 non-null  float64
#  8   dusage_sum                   10500 non-null  float64
#  9   dusage_min                   10500 non-null  float64
#  10  dusage_max                   10500 non-null  float64
#  11  dusage_avg                   9642 non-null   float64
#  12  dusage_days                  10500 non-null  float64
#  13  dusage_stddev                10500 non-null  float64
#  14  vusage_onnet_sum             10500 non-null  float64
#  15  vusage_onnet_max             10500 non-null  float64
#  16  vusage_onnet_min             10500 non-null  float64
#  17  vusage_onnet_days            10500 non-null  float64
#  18  vusage_onnet_avg             1828 non-null   float64
#  19  vusage_onnet_stddev          10500 non-null  float64
#  20  vusage_offnet_sum            10500 non-null  float64
#  21  vusage_offnet_max            10500 non-null  float64
#  22  vusage_offnet_min            10500 non-null  float64
#  23  vusage_offnet_days           10500 non-null  float64
#  24  vusage_offnet_avg            7187 non-null   float64
#  25  vusage_offnet_stddev         10500 non-null  float64
#  26  number_of_fixed_bb_accounts  10500 non-null  float64
#  27  number_of_iptv_accounts      10500 non-null  float64
#  28  add_on_tot_rental            6667 non-null   float64
#  29  add_on_count                 6667 non-null   float64
#  30  next_month_plan              10500 non-null  category
#  31  encoded_class_labels         10500 non-null  int64
# dtypes: category(1), float64(23), int64(3), object(5)
# memory usage: 2.5+ MB

# %%
train_data = train_data.dropna(subset = ['device_type', 'device_category', 'gender', 'age_group'], axis = 0)

# %%
train_data = train_data.drop(columns = ['next_month_plan', 'vusage_onnet_avg'])

# %%
train_data['dusage_avg'] = train_data['dusage_avg'].fillna(value = 0)
train_data['vusage_offnet_avg'] = train_data['vusage_offnet_avg'].fillna(value = 0)
train_data['add_on_tot_rental'] = train_data['add_on_tot_rental'].fillna(value = 0)
train_data['add_on_count'] = train_data['add_on_count'].fillna(value = 0)

# %%
train_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10337 entries, 0 to 10499
# Data columns (total 30 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   primary_identifier           10337 non-null  int64
#  1   device_type                  10337 non-null  object
#  2   device_category              10337 non-null  object
#  3   gender                       10337 non-null  object
#  4   district_name                10337 non-null  object
#  5   age_group                    10337 non-null  object
#  6   network_stay                 10337 non-null  int64
#  7   average_monthly_bill_amount  10337 non-null  float64
#  8   dusage_sum                   10337 non-null  float64
#  9   dusage_min                   10337 non-null  float64
#  10  dusage_max                   10337 non-null  float64
#  11  dusage_avg                   10337 non-null  float64
#  12  dusage_days                  10337 non-null  float64
#  13  dusage_stddev                10337 non-null  float64
#  14  vusage_onnet_sum             10337 non-null  float64
#  15  vusage_onnet_max             10337 non-null  float64
#  16  vusage_onnet_min             10337 non-null  float64
#  17  vusage_onnet_days            10337 non-null  float64
#  18  vusage_onnet_stddev          10337 non-null  float64
#  19  vusage_offnet_sum            10337 non-null  float64
#  20  vusage_offnet_max            10337 non-null  float64
#  21  vusage_offnet_min            10337 non-null  float64
#  22  vusage_offnet_days           10337 non-null  float64
#  23  vusage_offnet_avg            10337 non-null  float64
#  24  vusage_offnet_stddev         10337 non-null  float64
#  25  number_of_fixed_bb_accounts  10337 non-null  float64
#  26  number_of_iptv_accounts      10337 non-null  float64
#  27  add_on_tot_rental            10337 non-null  float64
#  28  add_on_count                 10337 non-null  float64
#  29  encoded_class_labels         10337 non-null  int64
# dtypes: float64(22), int64(3), object(5)
# memory usage: 2.4+ MB

# %%
train_data.columns
# Out:
# Index(['primary_identifier', 'device_type', 'device_category', 'gender',
#        'district_name', 'age_group', 'network_stay',
#        'average_monthly_bill_amount', 'dusage_sum', 'dusage_min', 'dusage_max',
#        'dusage_avg', 'dusage_days', 'dusage_stddev', 'vusage_onnet_sum',
#        'vusage_onnet_max', 'vusage_onnet_min', 'vusage_onnet_days',
#        'vusage_onnet_stddev', 'vusage_offnet_sum', 'vusage_offnet_max',
#        'vusage_offnet_min', 'vusage_offnet_days', 'vusage_offnet_avg',
#        'vusage_offnet_stddev', 'number_of_fixed_bb_accounts',
#        'number_of_iptv_accounts', 'add_on_tot_rental', 'add_on_count',
#        'encoded_class_labels'],
#       dtype='object')

# %%
data_cat_cols = ['device_type', 'device_category', 'gender', 'district_name', 'age_group']

# %%
data_quan_cols = ['network_stay','average_monthly_bill_amount', 'dusage_sum', 
                 'dusage_min', 'dusage_max','dusage_avg', 'dusage_days', 
                 'dusage_stddev', 'vusage_onnet_sum','vusage_onnet_max', 
                 'vusage_onnet_min', 'vusage_onnet_days','vusage_onnet_stddev', 
                 'vusage_offnet_sum', 'vusage_offnet_max','vusage_offnet_min', 
                 'vusage_offnet_days', 'vusage_offnet_avg','vusage_offnet_stddev', 
                 'number_of_fixed_bb_accounts','number_of_iptv_accounts', 
                 'add_on_tot_rental', 'add_on_count']

# %%
X = train_data.drop(columns=['encoded_class_labels', 'primary_identifier'])

# %%
y = train_data['encoded_class_labels']

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, y, random_state=10, test_size = 0.05, stratify = y)

# %%
X_train.head()
# Out:
#      device_type device_category  gender district_name age_group  \
# 825           4G      Smartphone  FEMALE       Gampaha     20-30
# 452           4G      Smartphone    MALE      Puttalam     20-30
# 3175          4G      Smartphone  FEMALE       Colombo     20-30
# 8908          4G      Smartphone    MALE       Colombo     20-30
# 3484          4G      Smartphone    MALE        Matara     30-40
#
#       network_stay  average_monthly_bill_amount  dusage_sum  dusage_min  \
# 825             78                      1883.00      8098.0   16.484163
# 452             74                      1235.68      4805.0    0.000000
# 3175            54                      4901.43      3065.0    0.000000
# 8908            78                      1442.65     13784.0  115.651798
# 3484           115                      2538.34      6119.0    4.909788
#
#        dusage_max  ...  vusage_offnet_sum  vusage_offnet_max  \
# 825   1193.490847  ...                0.0           0.000000
# 452    573.887156  ...              203.0          36.200000
# 3175   598.372708  ...                0.0           0.000000
# 8908   854.164129  ...               10.0           4.716667
# 3484  1376.794269  ...                4.0           4.116667
#
#       vusage_offnet_min  vusage_offnet_days  vusage_offnet_avg  \
# 825                 0.0                 0.0           0.000000
# 452                 0.0                24.0           8.468056
# 3175                0.0                 0.0           0.000000
# 8908                0.0                 7.0           1.542857
# 3484                0.0                 1.0           4.116667
#
#       vusage_offnet_stddev  number_of_fixed_bb_accounts  \
# 825               0.000000                          0.0
# 452               8.451039                          0.0
# 3175              0.000000                          0.0
# 8908              0.973741                          0.0
# 3484              0.751597                          0.0
#
#       number_of_iptv_accounts  add_on_tot_rental  add_on_count
# 825                       0.0              110.0           1.0
# 452                       0.0               50.0           1.0
# 3175                      0.0              160.0           2.0
# 8908                      0.0             1490.0           1.0
# 3484                      0.0                0.0           0.0
#
# [5 rows x 28 columns]

# %%
quan_pipeline = Pipeline([
    ('std_scaler', StandardScaler())
])

quan_transformed = quan_pipeline.fit_transform(X_train[data_quan_cols])

# %%
data_pipeline = ColumnTransformer([
    ('numerical', quan_pipeline, data_quan_cols),
    ('categorical', OneHotEncoder(), data_cat_cols),
    
])

train_data_processed = data_pipeline.fit_transform(X_train)

# %%
train_data_processed
# Out:
# array([[-0.19976851, -0.13366101, -0.29556044, ...,  0.        ,
#          0.        ,  0.        ],
#        [-0.25556159, -0.57975143, -0.50298003, ...,  0.        ,
#          0.        ,  0.        ],
#        [-0.53452702,  1.94644268, -0.6125792 , ...,  0.        ,
#          0.        ,  0.        ],
#        ...,
#        [ 0.24657618, -1.0374262 , -0.80563752, ...,  0.        ,
#          0.        ,  0.        ],
#        [-1.17614751, -0.75819587,  0.02259211, ...,  0.        ,
#          0.        ,  0.        ],
#        [-0.75769937, -0.19473209, -0.80563752, ...,  0.        ,
#          0.        ,  0.        ]])

# %%
X_test.head()
# Out:
#      device_type device_category gender district_name age_group  network_stay  \
# 1085          4G      Smartphone   MALE       Gampaha       >70           197
# 363           4G      Smartphone   MALE      Kalutara     30-40             6
# 3138          4G      Smartphone   MALE      Kalutara       >70           209
# 8803          4G      Smartphone   MALE        Ampara     30-40           110
# 2588          4G      Smartphone   MALE       Colombo     30-40            21
#
#       average_monthly_bill_amount  dusage_sum  dusage_min   dusage_max  ...  \
# 1085                      1779.12      3323.0    0.000000   979.542162  ...
# 363                       3090.40     20448.0   83.657084  1765.653071  ...
# 3138                      1221.33      5969.0   23.828087   457.254642  ...
# 8803                       905.32      5799.0    1.819816  1971.909241  ...
# 2588                      1481.54     26751.0  435.232862  2204.760595  ...
#
#       vusage_offnet_sum  vusage_offnet_max  vusage_offnet_min  \
# 1085                0.0           0.000000                0.0
# 363                 0.0           0.000000                0.0
# 3138               35.0          14.100000                0.0
# 8803                8.0           2.583333                0.0
# 2588                1.0           1.116667                0.0
#
#       vusage_offnet_days  vusage_offnet_avg  vusage_offnet_stddev  \
# 1085                 0.0           0.000000              0.000000
# 363                  0.0           0.000000              0.000000
# 3138                 8.0           4.397917              2.939344
# 8803                 4.0           2.112500              0.741921
# 2588                 2.0           0.866667              0.229473
#
#       number_of_fixed_bb_accounts  number_of_iptv_accounts  add_on_tot_rental  \
# 1085                          0.0                      0.0                0.0
# 363                           0.0                      0.0                0.0
# 3138                          0.0                      0.0                0.0
# 8803                          0.0                      0.0                0.0
# 2588                          0.0                      0.0              700.0
#
#       add_on_count
# 1085           0.0
# 363            0.0
# 3138           0.0
# 8803           0.0
# 2588           3.0
#
# [5 rows x 28 columns]

# %%
X_train.columns
# Out:
# Index(['device_type', 'device_category', 'gender', 'district_name',
#        'age_group', 'network_stay', 'average_monthly_bill_amount',
#        'dusage_sum', 'dusage_min', 'dusage_max', 'dusage_avg', 'dusage_days',
#        'dusage_stddev', 'vusage_onnet_sum', 'vusage_onnet_max',
#        'vusage_onnet_min', 'vusage_onnet_days', 'vusage_onnet_stddev',
#        'vusage_offnet_sum', 'vusage_offnet_max', 'vusage_offnet_min',
#        'vusage_offnet_days', 'vusage_offnet_avg', 'vusage_offnet_stddev',
#        'number_of_fixed_bb_accounts', 'number_of_iptv_accounts',
#        'add_on_tot_rental', 'add_on_count'],
#       dtype='object')

# %%
X_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 517 entries, 1085 to 3521
# Data columns (total 28 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   device_type                  517 non-null    object
#  1   device_category              517 non-null    object
#  2   gender                       517 non-null    object
#  3   district_name                517 non-null    object
#  4   age_group                    517 non-null    object
#  5   network_stay                 517 non-null    int64
#  6   average_monthly_bill_amount  517 non-null    float64
#  7   dusage_sum                   517 non-null    float64
#  8   dusage_min                   517 non-null    float64
#  9   dusage_max                   517 non-null    float64
#  10  dusage_avg                   517 non-null    float64
#  11  dusage_days                  517 non-null    float64
#  12  dusage_stddev                517 non-null    float64
#  13  vusage_onnet_sum             517 non-null    float64
#  14  vusage_onnet_max             517 non-null    float64
#  15  vusage_onnet_min             517 non-null    float64
#  16  vusage_onnet_days            517 non-null    float64
#  17  vusage_onnet_stddev          517 non-null    float64
#  18  vusage_offnet_sum            517 non-null    float64
#  19  vusage_offnet_max            517 non-null    float64
#  20  vusage_offnet_min            517 non-null    float64
#  21  vusage_offnet_days           517 non-null    float64
#  22  vusage_offnet_avg            517 non-null    float64
#  23  vusage_offnet_stddev         517 non-null    float64
#  24  number_of_fixed_bb_accounts  517 non-null    float64
#  25  number_of_iptv_accounts      517 non-null    float64
#  26  add_on_tot_rental            517 non-null    float64
#  27  add_on_count                 517 non-null    float64
# dtypes: float64(22), int64(1), object(5)
# memory usage: 117.1+ KB

# %%
test_data_processed = data_pipeline.transform(X_test)

# %%
test_data_processed
# Out:
# array([[ 1.4600758 , -0.20524828, -0.59632829, ...,  0.        ,
#          0.        ,  1.        ],
#        [-1.20404406,  0.69839976,  0.48234176, ...,  0.        ,
#          0.        ,  0.        ],
#        [ 1.62745506, -0.58964051, -0.42966196, ...,  0.        ,
#          0.        ,  1.        ],
#        ...,
#        [-0.71585455, -0.54605965, -0.79429968, ...,  0.        ,
#          0.        ,  0.        ],
#        [ 0.83240358, -0.73006541, -0.69685719, ...,  0.        ,
#          0.        ,  0.        ],
#        [-0.71585455, -0.54652137, -0.63487697, ...,  0.        ,
#          0.        ,  0.        ]])

# %%
model = GradientBoostingClassifier()

# %%
model.fit(train_data_processed, Y_train)
# Out:
# GradientBoostingClassifier()

# %%
y_pred = model.predict(test_data_processed)

# %%
print(y_pred)
# Out:
# [5 6 3 1 1 1 3 3 2 1 4 1 5 5 4 5 5 3 6 1 1 6 3 5 3 1 5 1 1 6 1 1 1 3 5 1 3
#  5 6 1 1 3 5 1 1 1 5 1 1 5 3 6 1 5 8 3 3 5 1 1 3 1 1 1 1 3 5 8 1 1 1 5 4 3
#  3 8 1 1 3 5 1 1 1 1 1 1 3 4 5 3 3 1 1 6 3 3 3 5 1 1 3 5 1 5 1 1 1 1 3 8 3
#  5 3 1 5 2 1 1 3 1 3 6 3 1 2 1 7 5 1 1 1 2 3 3 1 1 3 1 3 5 2 1 3 5 1 5 5 1
#  5 6 1 1 1 3 5 1 1 1 1 3 3 2 1 5 3 1 6 8 6 1 3 8 3 1 3 1 1 1 1 3 3 4 1 6 5
#  1 1 3 5 1 1 3 7 5 1 1 6 3 4 3 5 5 3 3 5 5 3 1 3 3 5 6 3 1 8 3 5 1 3 1 8 1
#  8 5 3 3 1 5 3 5 1 8 1 5 1 1 1 3 6 1 3 1 5 3 3 1 1 3 1 5 3 5 1 3 5 1 1 4 1
#  1 3 3 3 1 3 7 1 3 1 3 6 3 3 3 1 3 3 1 1 3 1 5 3 1 5 3 1 3 3 3 1 1 1 1 1 1
#  6 3 1 3 1 8 1 3 5 1 1 1 4 2 1 4 1 3 3 1 1 3 3 3 3 4 1 3 1 1 4 1 8 1 3 1 3
#  3 1 1 3 3 3 7 3 1 3 6 3 4 3 1 3 6 8 1 1 1 1 1 1 3 3 1 3 1 3 1 1 8 8 5 3 5
#  5 4 1 3 3 1 5 3 1 5 7 1 7 4 5 5 1 1 5 5 1 3 5 1 3 5 5 3 1 1 6 1 3 1 1 1 6
#  6 6 1 1 1 3 6 1 5 1 8 1 1 2 1 1 1 1 1 1 5 6 3 1 5 5 3 3 2 5 2 5 1 1 6 5 6
#  1 3 5 6 1 1 1 1 4 1 5 5 2 3 1 3 3 1 1 3 1 2 5 5 3 3 1 1 1 5 5 1 3 3 1 5 1
#  2 4 1 8 4 3 3 5 3 6 1 3 5 5 3 1 5 5 1 3 1 3 1 3 5 8 1 1 5 3 3 1 3 1 1 3]

# %%
confusion_matrix(Y_test, y_pred)
# Out:
# array([[146,   1,  25,   3,   5,   1,   0,   0],
#        [ 39,   7,  19,   2,   0,   0,   0,   0],
#        [ 16,   1,  63,   5,   0,   0,   0,   0],
#        [  2,   2,  25,   3,   3,   0,   0,   1],
#        [  4,   2,   7,   2,  54,   7,   0,   1],
#        [  0,   0,   1,   2,  18,  12,   0,   3],
#        [  1,   0,   1,   0,   5,   3,   4,   4],
#        [  0,   0,   0,   0,   0,   6,   2,   9]])

# %%
# Getting f1 score
from sklearn.metrics import classification_report
print(classification_report(Y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            1       0.70      0.81      0.75       181
#            2       0.54      0.10      0.18        67
#            3       0.45      0.74      0.56        85
#            4       0.18      0.08      0.11        36
#            5       0.64      0.70      0.67        77
#            6       0.41      0.33      0.37        36
#            7       0.67      0.22      0.33        18
#            8       0.50      0.53      0.51        17
#
#     accuracy                           0.58       517
#    macro avg       0.51      0.44      0.43       517
# weighted avg       0.56      0.58      0.54       517

# %%
np.arange(50,300, 25)

# %%
gb_params = {
    'learning_rate' : np.linspace(1.0, 0.001, num=20),
    'loss': ['deviance', 'exponential'],
    'n_estimators': np.arange(50,300, 25),
    'criterion': ['friedman_mse', 'mse', 'mae'],
    'max_depth': range(1,10),
    'max_features' : ['auto', 'sqrt', 'log2']
}

# %%
gb_model = GradientBoostingClassifier()
model_gb = RandomizedSearchCV(gb_model, gb_params, cv=5, n_jobs = -1, verbose = 1, n_iter = 1000)
model_gb.fit(train_data_processed, Y_train)

# %%
model_gb.best_params_

# %%
model_gb.best_score_

# %%
tuned_model = GradientBoostingClassifier(learning_rate = , loss = , n_estimators = , criterion = , max_depth = ,
                                        max_features = )

# %%
tuned_model.fit(train_data_processed, Y_train)

# %%
y_pred = tuned_model.predict(test_data_processed)

# %%
# Getting f1 score
from sklearn.metrics import classification_report
print(classification_report(Y_test, y_pred))

# %%
import cPickle
# save the classifier
with open('my_dumped_classifier.pkl', 'wb') as fid:
    cPickle.dump(gnb, fid)
